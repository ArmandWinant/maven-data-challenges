# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exped_df = pd.read_csv('./data/exped.csv', low_memory=False)
member_df = pd.read_csv('./data/members.csv', low_memory=False)
peak_df = pd.read_csv('./data/peaks.csv', low_memory=False)

# %%
exped_df.loc[(exped_df.year == 1981) & (exped_df.host == 'Nepal'), :]
# Out:
#           expid peakid  year  season   host                       route1  \
# 7     ANN281302   ANN2  1981  Autumn  Nepal             NW Ridge-W Ridge
# 8     ANN281301   ANN2  1981  Autumn  Nepal              S Ridge/SE Face
# 35    ANN481101   ANN4  1981  Spring  Nepal                     NW Ridge
# 36    ANN481301   ANN4  1981  Autumn  Nepal                     NW Ridge
# 37    ANN481401   ANN4  1981  Winter  Nepal              N Face-NW Ridge
# ...         ...    ...   ...     ...    ...                          ...
# 3086  YALU81102   YALU  1981  Spring  Nepal                      SE Face
# 3627  ANN181102   ANN1  1981  Spring  Nepal  S Face (E of Bonington rte)
# 3629  CHUL81301   CHUL  1981  Autumn  Nepal                      W Ridge
# 3947  GAN681101   GAN6  1981  Spring  Nepal                     SE Ridge
# 9765  TARS81301   TARS  1981  Autumn  Nepal                       N Face
#
#      route2 route3 route4     nation  ...  \
# 7       NaN    NaN    NaN      Italy  ...
# ...

# %%
member_df.loc[member_df.sex == 'M', :].head(100)
# Out:
#          expid  membid peakid  myear mseason         fname      lname sex  \
# 0    AMAD01101       2   AMAD   2001  Spring         Rohan    Buckley   M
# 1    AMAD01101       1   AMAD   2001  Spring  Marc Cameron   Fairhead   M
# 2    AMAD01101       3   AMAD   2001  Spring          Mark  Schroeder   M
# 3    AMAD01101       4   AMAD   2001  Spring         Colin      Smith   M
# 5    AMAD01102       1   AMAD   2001  Spring        Sergei  Menchenin   M
# ..         ...     ...    ...    ...     ...           ...        ...  ..
# 105  CHOY01106       3   CHOY   2001  Spring       Michael     Bindig   M
# 106  CHOY01106       4   CHOY   2001  Spring        Lothar      Dedek   M
# 107  CHOY01106       5   CHOY   2001  Spring       Hermann  Eisenhans   M
# 108  CHOY01106       6   CHOY   2001  Spring        Albert   Gelhardt   M
# 109  CHOY01106       7   CHOY   2001  Spring        Stefan     Graeff   M
#
#         yob    citizen  ...  death deathdate deathtime  deathtype  deathhgtm  \
# ...

# %%
peak_df.head(10)
# Out:
#   peakid         pkname          pkname2  \
# 0   ACHN         Aichyn   Aychin, Ashvin
# 1   AMAD     Ama Dablam     Amai Dablang
# 2   AMOT       Amotsang          Amatson
# 3   AMPG  Amphu Gyabjen    Amphu Gyabien
# 4   AMPH        Amphu I              NaN
# 5   AMPM   Amphu Middle      Amphu North
# 6   ANID  Anidesh Chuli  White Wave Peak
# 7   ANN1    Annapurna I              NaN
# 8   ANN2   Annapurna II              NaN
# 9   ANN3  Annapurna III              NaN
#
#                                           location  heightm  heightf  \
# 0                Chandi Himal (SW of Changwathang)     6055    19865
# 1                                     Khumbu Himal     6814    22356
# 2                  Damodar Himal (NW of Pokharhan)     6393    20974
# 3                   Khumbu Himal (N of Ama Dablam)     5630    18471
# 4  Khumbu Himal (E of Amphu Laptsa, W of Baruntse)     6740    22113
# 5                Khumbu Himal (NW of Amphu Laptsa)     6202    20348
# ...
